# %%
import pandas as pd
import numpy as np
import re

import plotly.plotly as py
import plotly.graph_objs as go 
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
#temp = pd.read_csv('GlobalTemps.csv')
coemm = pd.read_csv('CO2Emm_Global_1970-16.csv')
engcons = pd.read_csv('EU_EngConsPerCap_00-16.csv')

# %% [markdown]
# # Data cleaning

# %%
coemm.head()
# Out:
#   ISO_CODE     ISO_NAME  Year  GHG per capita emissions   CO2/cap
# 0      AFG  Afghanistan  1970                  1.557705  0.156962
# 1      ALB      Albania  1970                  3.355742  2.062545
# 2      DZA      Algeria  1970                  4.645362  1.207575
# 3      AGO       Angola  1970                  6.772412  1.191541
# 4      AIA     Anguilla  1970                  0.776791  0.338751

# %%
coemm['Year'].max()
# Out:
# 2016

# %%
coemm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9870 entries, 0 to 9869
# Data columns (total 5 columns):
# ISO_CODE                    9870 non-null object
# ISO_NAME                    9870 non-null object
# Year                        9870 non-null int64
# GHG per capita emissions    9030 non-null float64
# CO2/cap                     9870 non-null float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 385.6+ KB

# %%
engcons.head()
# Out:
#    Year kg of oil equivalent per capita                 Country
# 0  2000                            123                  Albania
# 1  2000                            791                  Austria
# 2  2000                              0   Bosnia and Herzegovina
# 3  2000                            924                  Belgium
# 4  2000                            264                 Bulgaria

# %%
engcons['Year'].max()
# Out:
# 2016

# %%
engcons['Country'].unique()
# Out:
# array(['Albania', 'Austria', 'Bosnia and Herzegovina', 'Belgium',
#        'Bulgaria', 'Cyprus', 'Czech Republic', 'Germany', 'Denmark',
#        'Estonia', 'Greece', 'Spain', 'Finland', 'France', 'Croatia',
#        'Hungary', 'Ireland', 'Iceland', 'Italy', 'Lithuania',
#        'Luxembourg', 'Latvia', 'Montenegro', 'Macedonia', 'Malta',
#        'Netherlands', 'Norway', 'Poland', 'Portugal', 'Romania', 'Serbia',
#        'Sweden', 'Slovenia', 'Slovakia', 'Turkey', 'United Kingdom',
#        'Kosovo'], dtype=object)

# %%
coemm = coemm[coemm['Year'] > 1999]

# %%
coemm.reset_index().drop(['index'],axis=1,inplace=True)

# %% [markdown]
# # Renaming country names to match engcons dataframe
#
# - coemm has different country names to engcons
# - attempted to rename one country first

# %%
# Grab string to rename
# To be iterated
uk_str = coemm[coemm['ISO_NAME'].str.contains('United Kingdom')]['ISO_NAME'].iloc[0]
print(uk_str)
# Out:
# United Kingdom of Great Britain and Northern Ireland (the)

# %%
# Replace sliced column with renamed column
# To be iterated
# uk_renamed = coemm.loc[coemm['ISO_NAME'] == uk_str]
# uk_renamed = uk_renamed.replace(to_replace={'ISO_NAME':{uk_str:'United Kingdom'}})

coemm['ISO_NAME'] = coemm['ISO_NAME'].replace({uk_str:'United Kingdom'})

# %%
# Check if rename was successful
coemm[coemm['ISO_NAME'] == 'United Kingdom'].head()
# Out:
#      ISO_CODE        ISO_NAME  Year  GHG per capita emissions   CO2/cap
# 6497      GBR  United Kingdom  2000                  11.75803  9.225049
# 6707      GBR  United Kingdom  2001                  11.84552  9.436021
# 6917      GBR  United Kingdom  2002                  11.47246  9.110215
# 7127      GBR  United Kingdom  2003                  11.56776  9.281403
# 7337      GBR  United Kingdom  2004                  11.39856  9.227768

# %%
# Iterate

# %%
engcons_country_list = engcons['Country'].unique().tolist()

# %%
# To pick up errors where names are different
# For example Czechia and Czech Republic name difference
# Kosovo, status disputed according to Wikipedia
# For simplicity they will be removed
to_be_renamed_list = []
for i in range(engcons_range):
    try:
        to_be_renamed_list.append(coemm[coemm['ISO_NAME'].str.contains(engcons_country_list[i])]['ISO_NAME'].iloc[0])
    except IndexError:
        pass

# %%
# Removed Czech Republic and Kosovo
engcons_country_list = [e for e in engcons_country_list if e not in ('Czech Republic', 'Kosovo')]
engcons_range = len(engcons_country_list)

# %%
# Now I can iterate without error handling
to_be_renamed_list = []
for i in range(engcons_range):
        to_be_renamed_list.append(coemm[coemm['ISO_NAME'].str.contains(engcons_country_list[i])]['ISO_NAME'].iloc[0])

# %%
# Replace sliced column with renamed column
for j in range(engcons_range):
    coemm['ISO_NAME'] = coemm['ISO_NAME'].replace({to_be_renamed_list[j]:engcons_country_list[j]})

# %%
coemm[coemm['ISO_NAME'] == 'United Kingdom'].head()
# Out:
#      ISO_CODE        ISO_NAME  Year  GHG per capita emissions   CO2/cap
# 197       GBR  United Kingdom  1970                  15.76062  12.13728
# 407       GBR  United Kingdom  1971                  15.64406  11.94266
# 617       GBR  United Kingdom  1972                  15.07697  11.52187
# 827       GBR  United Kingdom  1973                  15.73715  12.06927
# 1037      GBR  United Kingdom  1974                  14.93535  11.27633

# %%
# Checking where I cut off 2012-2016 when I merged coemm and engcons
# This was due to the two country columns not having the same names
coemm['Year'].max()
# Out:
# 2016

# %%
coemm = coemm.reset_index().drop(['index'],axis=1)

# %%
coemm.rename(columns={"ISO_NAME":"Country","ISO_CODE":"Code"},inplace=True)

# %%
merged = coemm.merge(engcons, how='inner', on=['Year', 'Country'])

# %%
# Merged data has 2013-2016 data missing due to name difference
merged['Year'].max()
# Out:
# 2016

# %%
merged.head()
# Out:
#   Code                 Country  Year  GHG per capita emissions    CO2/cap  \
# 0  ALB                 Albania  2000                  2.320918   1.006200
# 1  AUT                 Austria  2000                 10.368110   8.220142
# 2  BEL                 Belgium  2000                 14.673130  11.852220
# 3  BIH  Bosnia and Herzegovina  2000                  4.694694   3.774173
# 4  BGR                Bulgaria  2000                  7.603958   5.878875
#
#   kg of oil equivalent per capita
# 0                            123
# 1                            791
# 2                            924
# 3                              0
# 4                            264

# %%
# merged = merged.reset_index().drop(['index'],axis=1)

# %%
merged.columns = [x.lower() for x in merged.columns]

# %%
merged.head()
# Out:
#   code                 country  year  ghg per capita emissions    co2/cap  \
# 0  ALB                 Albania  2000                  2.320918   1.006200
# 1  AUT                 Austria  2000                 10.368110   8.220142
# 2  BEL                 Belgium  2000                 14.673130  11.852220
# 3  BIH  Bosnia and Herzegovina  2000                  4.694694   3.774173
# 4  BGR                Bulgaria  2000                  7.603958   5.878875
#
#   kg of oil equivalent per capita
# 0                            123
# 1                            791
# 2                            924
# 3                              0
# 4                            264

# %% [markdown]
# # Map plotting

# %%
merged_2000 = merged[merged['year'] == 2000]

# %%
data = dict(
        type = 'choropleth',
        locations = merged_2000['code'],
        z = merged_2000['ghg per capita emissions'],
        text = merged_2000['country'],
        colorbar = {'title' : 'GHG Emissions'},)

# %%
layout = dict(
    title = '2000 Greenhouse Gas Emissions',
    geo = dict(
        scope = 'europe'))

# %%
choromap = dict(data = [data],layout = layout)
iplot(choromap)
# Out:
# <div id="01fe910c-02de-452e-b145-5087fa62ec2d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("01fe910c-02de-452e-b145-5087fa62ec2d", [{"colorbar": {"title": {"text": "GHG Emissions"}}, "locations": ["ALB", "AUT", "BIH", "BEL", "BGR", "CYP", "DEU", "DNK", "EST", "GRC", "FIN", "HRV", "HUN", "IRL", "ISL", "LTU", "LUX", "LVA", "MLT", "NOR", "POL", "PRT", "ROU", "SWE", "SVN", "SVK", "TUR"], "text": ["Albania", "Austria", "Bosnia and Herzegovina", "Belgium", "Bulgaria", "Cyprus", "Germany", "Denmark", "Estonia", "Greece", "Finland", "Croatia", "Hungary", "Ireland", "Iceland", "Lithuania", "Luxembourg", "Latvia", "Malta", "Norway", "Poland", "Portugal", "Romania", "Sweden", "Slovenia", "Slovakia", "Turkey"], "z": [2.320918, 10.36811, 4.694694, 14.67313, 7.603958, 9.26927, 12.44737, 13.10253, 13.45195, 11.33651, 15.34886, 5.843751, 7.279392, 18.21754, 13.28975, 5.663677, 22.1171, 4.5234510000000006, 5.911014, 14.86427, 10.55341, 7.902765, 5.789295, 8.813474000000003, 10.59332, 9.566424, 5.312551999999998], "type": "choropleth", "uid": "59feadbc-f311-4926-b46f-bacacdefd2d9"}], {"geo": {"scope": "europe"}, "title": {"text": "2000 Greenhouse Gas Emissions"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("01fe910c-02de-452e-b145-5087fa62ec2d"));});</script>

# %%
# Create a list for year
years_list = list(merged['year'].unique().astype(str))

# %%
merged_piv = merged.pivot_table(index=['code'],columns='year', values='co2/cap')

# %%
merged_piv.head()
# Out:
# year       2000       2001       2002       2003       2004       2005  \
# code
# ALB    1.006200   1.075421   1.248918   1.350672   1.409903   1.344544
# AUT    8.220142   8.765426   8.950900   9.544022   9.640830   9.736343
# BEL   11.852220  11.818720  11.038010  11.740840  11.347100  10.921950
# BGR    5.878875   6.199531   5.909999   6.728912   6.558176   6.754750
# BIH    3.774173   3.723906   3.911332   4.002134   4.227815   4.434418
#
# year       2006       2007       2008      2009      2010      2011      2012  \
# code
# ALB    1.343873   1.394059   1.395093  1.265050  1.384648  1.476388  1.441218
# AUT    9.373612   9.082319   9.143795  8.203180  8.930128  8.792819  8.610191
# BEL   10.586760  10.140010  10.414670  9.338250  9.946639  8.962264  8.440513
# BGR    6.977927   7.537460   7.199023  6.161931  6.566002  7.285842  7.251792
# BIH    4.929181   5.206201   5.725029  5.715470  5.903874  6.715541  6.668547
#
# year      2013      2014      2015      2016
# code
# ALB   1.501637  1.650724  1.707743  1.777583
# AUT   8.593714  8.121575  8.369108  8.468899
# BEL   8.474506  7.978163  8.256059  8.309019
# BGR   6.542882  7.048781  7.537466  7.135051
# BIH   6.702908  6.831988  7.190721  7.293784

# %%
merged_piv.reset_index(inplace=True)

# %%
merged_piv.columns = ['code']+years_list

# %%
merged_piv.head()
# Out:
#   code       2000       2001       2002       2003       2004       2005  \
# 0  ALB   1.006200   1.075421   1.248918   1.350672   1.409903   1.344544
# 1  AUT   8.220142   8.765426   8.950900   9.544022   9.640830   9.736343
# 2  BEL  11.852220  11.818720  11.038010  11.740840  11.347100  10.921950
# 3  BGR   5.878875   6.199531   5.909999   6.728912   6.558176   6.754750
# 4  BIH   3.774173   3.723906   3.911332   4.002134   4.227815   4.434418
#
#         2006       2007       2008      2009      2010      2011      2012  \
# 0   1.343873   1.394059   1.395093  1.265050  1.384648  1.476388  1.441218
# 1   9.373612   9.082319   9.143795  8.203180  8.930128  8.792819  8.610191
# 2  10.586760  10.140010  10.414670  9.338250  9.946639  8.962264  8.440513
# 3   6.977927   7.537460   7.199023  6.161931  6.566002  7.285842  7.251792
# 4   4.929181   5.206201   5.725029  5.715470  5.903874  6.715541  6.668547
#
#        2013      2014      2015      2016
# 0  1.501637  1.650724  1.707743  1.777583
# 1  8.593714  8.121575  8.369108  8.468899
# 2  8.474506  7.978163  8.256059  8.309019
# 3  6.542882  7.048781  7.537466  7.135051
# 4  6.702908  6.831988  7.190721  7.293784

# %% [markdown]
# ### Adding a drop down list

# %%
data_all = []

# %%
data_2000 = [dict(type='choropleth',
                locations = merged_piv['code'],
                z = merged_piv['2000'],
                text = merged_piv['code'],
                colorbar = dict(title = "CO2"))]
    
data_all.extend(data_2000)

# %%
for i in years[1:]:
    data_upd = [dict(type='choropleth',
                      locations = merged_piv['code'],
                      z = merged_piv[i],
                      text = merged_piv['code'],
                      colorbar = dict(title = "CO2"))]
    
    data_all.extend(data_upd)

# %%
# menus inside plot
steps = []
yr = 0
for i in range(0,len(data_all)):
    step = dict(method = "restyle",
                args = ["visible", [False]*len(data_all)],
                label = years[yr]) 
    step['args'][1][i] = True
    steps.append(step)
    yr += 1

sliders = [dict(active = 10,
                currentvalue = {"prefix": "Year: "},
                pad = {"t": 50},
                steps = steps)]

# %%
# set the layout
layout = dict(title = 'CO2',
              geo = dict(scope='europe'
                        ),
              sliders = sliders
             )

# %%
fig = dict(data=data_all, layout=layout)
iplot(fig, filename='d3-cloropleth-map')
# Out:
# <div id="43226b01-193c-4095-8285-be1dc8a91aed" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("43226b01-193c-4095-8285-be1dc8a91aed", [{"colorbar": {"title": {"text": "CO2"}}, "locations": ["ALB", "AUT", "BEL", "BGR", "BIH", "CYP", "DEU", "DNK", "ESP_AND", "EST", "FIN", "FRA_MCO", "GBR", "GRC", "HRV", "HUN", "IRL", "ISL", "ITA_SMR_VAT", "LTU", "LUX", "LVA", "MKD", "MLT", "NLD", "NOR", "POL", "PRT", "ROU", "SRB_MNE", "SVK", "SVN", "SWE", "TUR"], "text": ["ALB", "AUT", "BEL", "BGR", "BIH", "CYP", "DEU", "DNK", "ESP_AND", "EST", "FIN", "FRA_MCO", "GBR", "GRC", "HRV", "HUN", "IRL", "ISL", "ITA_SMR_VAT", "LTU", "LUX", "LVA", "MKD", "MLT", "NLD", "NOR", "POL", "PRT", "ROU", "SRB_MNE", "SVK", "SVN", "SWE", "TUR"], "z": [1.0062, 8.220142, 11.85222, 5.878875, 3.774173, 7.424202, 10.50823, 9.995957, 7.477778, 10.91783, 11.45079, 6.604883999999998, 9.225049, 8.662127, 4.364039, 5.68613, 11.39304, 10.19513, 7.904153999999999, 3.321656, 19.96135, 3.062718, 4.436083, 5.37425, 10.52679, 9.19123, 8.019102, 6.118901, 4.36224, 5.006402, 7.945479, 7.923619, 6.4687800000000015, 3.5898], "type": "choropleth", "uid": "065e554f-2279-4808-80be-635f9f834ba8"}, {"colorbar": {"title": {"text": "CO2"}}, "locations": ["ALB", "AUT", "BEL", "BGR", "BIH", "CYP", "DEU", "DNK", "ESP_AND", "EST", "FIN", "FRA_MCO", "GBR", "GRC", "HRV", "HUN", "IRL", "ISL", "ITA_SMR_VAT", "LTU", "LUX", "LVA", "MKD", "MLT", "NLD", "NOR", "POL", "PRT", "ROU", "SRB_MNE", "SVK", "SVN", "SWE", "TUR"], "text": ["ALB", "AUT", "BEL", "BGR", "BIH", "CYP", "DEU", "DNK", "ESP_AND", "EST", "FIN", "FRA_MCO", "GBR", "GRC", "HRV", "HUN", "IRL", "ISL", "ITA_SMR_VAT", "LTU", "LUX", "LVA", "MKD", "MLT", "NLD", "NOR", "POL", "PRT", "ROU", "SRB_MNE", "SVK", "SVN", "SWE", "TUR"], "z": [1.075421, 8.765426, 11.81872, 6.199531, 3.723906, 7.134817, 10.71097, 10.25863, 7.388985000000001, 11.39711, 12.5075, 6.676011999999999, 9.436021, 8.77132, 4.632797, 5.8211260000000005, 11.78769, 10.45972, 7.866075, 3.562318, 21.08929, 3.2387740000000003, 4.504813, 6.249556, 10.76901, 9.265833, 7.94118, 6.051539, 4.652146, 5.435322, 7.903614, 8.789133999999999, 6.454038, 3.215419], "type": "choropleth", "uid": "1021c8dd-abe6-4a3c-90a9-e846347457b8"}, {"colorbar": {"title": {"text": "CO2"}}, "locations": ["ALB", "AUT", "BEL", "BGR", "BIH", "CYP", "DEU", "DNK", "ESP_AND", "EST", "FIN", "FRA_MCO", "GBR", "GRC", "HRV", "HUN", "IRL", "ISL", "ITA_SMR_VAT", "LTU", "LUX", "LVA", "MKD", "MLT", "NLD", "NOR", "POL", "PRT", "ROU", "SRB_MNE", "SVK", "SVN", "SWE", "TUR"], "text": ["ALB", "AUT", "BEL", "BGR", "BIH", "CYP", "DEU", "DNK", "ESP_AND", "EST", "FIN", "FRA_MCO", "GBR", "GRC", "HRV", "HUN", "IRL", "ISL", "ITA_SMR_VAT", "LTU", "LUX", "LVA", "MKD", "MLT", "NLD", "NOR", "POL", "PRT", "ROU", "SRB_MNE", "SVK", "SVN", "SWE", "TUR"], "z": [1.248918, 8.9509, 11.03801, 5.909999, 3.911332, 7.203274, 10.5195, 10.15921, 7.720639999999999, 10.99714, 12.93722, 6.568275, 9.110215, 8.772021, 4.824803, 5.750416, 11.36929, 10.87471, 7.965142, 3.62542, 22.45369, 3.262226, 4.2251, 5.7926910000000005, 10.77331, 9.057727, 7.648903, 6.441227, 4.663221, 5.809141, 7.831523, 8.860653, 6.573872, 3.335943], "type": "choropleth", "uid": "e3b6ba8a-bccb-4dfd-94e9-6a25878be768"}, {"colorbar": {"title": {"text": "CO2"}}, "locations": ["ALB", "AUT", "BEL", "BGR", "BIH", "CYP", "DEU", "DNK", "ESP_AND", "EST", "FIN", "FRA_MCO", "GBR", "GRC", "HRV", "HUN", "IRL", "ISL", "ITA_SMR_VAT", "LTU", "LUX", "LVA", "MKD", "MLT", "NLD", "NOR", "POL", "PRT", "ROU", "SRB_MNE", "SVK", "SVN", "SWE", "TUR"], "text": ["ALB", "AUT", "BEL", "BGR", "BIH", "CYP", "DEU", "DNK", "ESP_AND", "EST", "FIN", "FRA_MCO", "GBR", "GRC", "HRV", "HUN", "IRL", "ISL", "ITA_SMR_VAT", "LTU", "LUX", "LVA", "MKD", "MLT", "NLD", "NOR", "POL", "PRT", "ROU", "SRB_MNE", "SVK", "SVN", "SWE", "TUR"], "z": [1.350672, 9.54 ...
